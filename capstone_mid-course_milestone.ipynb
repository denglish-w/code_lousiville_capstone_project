# %%
# Mid-Course Milestone: Guidelines and Submission
# Repository must include: 
    # Your completed notebook:demonstrated data cleaning and wrangling, EDA, at least 3 meaningful visualizations, explanatory markdown cells throughout the notebook
    # At least one data source
    # README.md file
    # requirements.txt file.

# %%
# miscellaneous container
    # potential api that has tree canopy data from 2019 'https://gis.lojic.org/maps/rest/services/LojicSolutions/OpenDataBase/MapServer/6'

# %%
# imports
import requests
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
# Show all data outputs
pd.set_option('display.max_rows', 200) 
pd.set_option('display.max_columns', None)

# %%
# load csv data
df = pd.read_csv(r'C:\Users\coldt\Code_You_Projects\capstone_project\code_lousiville_capstone_project\data\Jefferson_County_KY_Urban_Heat_Management_Study (1).csv')
print(df)
# Out:
#       OBJECTID       X       Y  CELL_A  KEYID  HEAT_DEATH  WS_B_APAVG  \
# 0            1  963120 -162480  230400    412    0.012036      75.995
# 1            2  963600 -162480  230400    413    0.000112      75.991
# 2            3  964080 -162480  230400    414    0.000081      76.041
# 3            4  963120 -162000  230400    612    0.004389      78.060
# 4            5  963600 -162000  230400    613    0.002889      77.806
# ...        ...     ...     ...     ...    ...         ...         ...
# 4919      4920  986640 -117360  230400  19261    0.000000      76.619
# 4920      4921  984240 -116880  230400  19456    0.000000      75.382
# 4921      4922  984720 -116880  230400  19457    0.000000      75.696
# 4922      4923  985200 -116880  230400  19458    0.000000      77.444
# 4923      4924  985680 -116880  230400  19459    0.000000      77.310
#
#       WS_B_APMIN  WS_B_APMAX  BASE_UHI  CC_FST_DEC  CC_FST_CON  CC_FST_MIX  \
# ...

# %%
df.shape
# Out:
# (4924, 96)

# %%
df.describe()
# Out:
#           OBJECTID             X              Y    CELL_A         KEYID  \
# count  4924.000000  4.924000e+03    4924.000000    4924.0   4924.000000
# mean   2462.500000  9.855122e+05 -138678.472786  230400.0  10375.953493
# std    1421.580693  1.182425e+04    9099.226849       0.0   3801.365967
# min       1.000000  9.626400e+05 -162960.000000  230400.0    214.000000
# 25%    1231.750000  9.751200e+05 -145680.000000  230400.0   7487.750000
# 50%    2462.500000  9.861600e+05 -138960.000000  230400.0  10276.500000
# 75%    3693.250000  9.952800e+05 -131760.000000  230400.0  13270.250000
# max    4924.000000  1.007280e+06 -116880.000000  230400.0  19459.000000
#
#         HEAT_DEATH   WS_B_APAVG   WS_B_APMIN   WS_B_APMAX     BASE_UHI  ...  \
# count  4924.000000  4924.000000  4924.000000  4924.000000  4924.000000  ...
# mean      0.017539    76.293762    65.000090    87.236333     0.010736  ...
# std       0.033817     0.913556     1.758595     0.702179     0.021090  ...
# ...

# %%
df.dtypes
# Out:
# OBJECTID       int64
# X              int64
# Y              int64
# CELL_A         int64
# KEYID          int64
#               ...
# AV_GREEN     float64
# AV_WASTE     float64
# AV_ALL       float64
# SHAPEAREA    float64
# SHAPELEN     float64
# Length: 96, dtype: object
